# %% [markdown]
# # 1. Setup

# %%
import numpy as np
import pandas as pd
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from utils.dataprep import load_and_preprocess_data

# %%
file_name = '../data/graduate-employment-survey-ntu-nus-sit-smu-suss-sutd.csv'
clean_target_columns = ['basic_monthly_mean']

# %%
df = load_and_preprocess_data(file_name, clean_target_columns)

# %% [markdown]
# # 2. Basic dataframe commands

# %%
df.head()
# Out:
#    year                        university  \
# 0  2013  Nanyang Technological University
# 1  2013  Nanyang Technological University
# 2  2013  Nanyang Technological University
# 3  2013  Nanyang Technological University
# 4  2013  Nanyang Technological University
#
#                                           school  \
# 0  College of Business (Nanyang Business School)
# 1  College of Business (Nanyang Business School)
# 2  College of Business (Nanyang Business School)
# 3  College of Business (Nanyang Business School)
# 4                         College of Engineering
#
#                                         degree  employment_rate_overall  \
# 0                     Accountancy and Business                     97.4
# 1  Accountancy (3-yr direct Honours Programme)                     97.1
# 2     Business (3-yr direct Honours Programme)                     90.9
# 3                       Business and Computing                     87.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 630 entries, 0 to 702
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       630 non-null    int64
#  1   university                 630 non-null    object
#  2   school                     621 non-null    object
#  3   degree                     630 non-null    object
#  4   employment_rate_overall    630 non-null    float64
#  5   employment_rate_ft_perm    630 non-null    float64
#  6   basic_monthly_mean         630 non-null    float64
#  7   basic_monthly_median       630 non-null    float64
#  8   gross_monthly_mean         630 non-null    float64
#  9   gross_monthly_median       630 non-null    float64
#  10  gross_mthly_25_percentile  630 non-null    float64
#  11  gross_mthly_75_percentile  630 non-null    float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 64.0+ KB

# %%
df.describe(include='all')
# Out:
#                year                        university                  school  \
# count    630.000000                               630                     621
# unique          NaN                                 6                      58
# top             NaN  National University of Singapore  College of Engineering
# freq            NaN                               207                      82
# mean    2015.687302                               NaN                     NaN
# std        1.661018                               NaN                     NaN
# min     2013.000000                               NaN                     NaN
# 25%     2014.000000                               NaN                     NaN
# 50%     2016.000000                               NaN                     NaN
# 75%     2017.000000                               NaN                     NaN
# max     2018.000000                               NaN                     NaN
#
# ...

# %% [markdown]
# # 3. General data

# %%
df.sort_values(by=['school'])
# Out:
#      year                                     university  \
# 0    2013               Nanyang Technological University
# 571  2018               Nanyang Technological University
# 570  2018               Nanyang Technological University
# 441  2017               Nanyang Technological University
# 195  2015               Nanyang Technological University
# ..    ...                                            ...
# 435  2016  Singapore University of Technology and Design
# 436  2016  Singapore University of Technology and Design
# 566  2017  Singapore University of Technology and Design
# 567  2017  Singapore University of Technology and Design
# 568  2017  Singapore University of Technology and Design
#
#                                             school  \
# 0    College of Business (Nanyang Business School)
# 571  College of Business (Nanyang Business School)
# 570  College of Business (Nanyang Business School)
# 441  College of Business (Nanyang Business School)
# ...

# %%
df[df['school'].isnull()]
# Out:
#      year                                     university school  \
# 285  2015  Singapore University of Technology and Design    NaN
# 286  2015  Singapore University of Technology and Design    NaN
# 287  2015  Singapore University of Technology and Design    NaN
# 434  2016  Singapore University of Technology and Design    NaN
# 435  2016  Singapore University of Technology and Design    NaN
# 436  2016  Singapore University of Technology and Design    NaN
# 566  2017  Singapore University of Technology and Design    NaN
# 567  2017  Singapore University of Technology and Design    NaN
# 568  2017  Singapore University of Technology and Design    NaN
#
#                                                 degree  \
# 285  Bachelor of Engineering (Engineering Product D...
# 286  Bachelor of Engineering (Engineering Systems a...
# 287  Bachelor of Engineering (Information Systems T...
# 434  Bachelor of Engineering (Engineering Product D...
# ...
